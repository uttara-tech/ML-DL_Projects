# %% [markdown]
# # Pneumonia Detection - VRAM optimization

# %% [markdown]
# <font color='green'> <br>
#     ***********************************************************************************************  <br><br>
#     &emsp; Deep Learning Project:&emsp; Multi-class classification <br><br>
#     &emsp; Author:&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp; Uttara Naidu <br><br>
#     &emsp; Date:&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 10/02/2026 <br><br>
#     &emsp; Version: &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;v0.1 (WIP) <br><br>
#     &emsp; Description:&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; Implements a U-NET for multi-class classification <br><br>
#     ***********************************************************************************************  <br>
#  </font>
#
# <font color='blue'> NOTE: This is an initial draft version. Code clean-up and optimizations will follow soon. </font>

# %% [markdown]
# ### For this U-NET model, input images were downsampled to meet memory constraints (32GB RAM) while maintaining representative features. If you wish to execute this notebook, please modify IMAGE_HEIGHT and IMAGE_WIDTH values to '128' in data_pipeline_operations.py.
#
# ### All other paramters and overall flow is exactly the same as in the main notebook 'pneumonia-detection.ipynb'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys, warnings, json
warnings.filterwarnings('ignore')
from collections import defaultdict
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, roc_auc_score, roc_curve, auc

# %%
""" 
    Download dataset 'covid19-radiography-database' from Kaggle
"""

try:
    with open("config.json") as f:
        js = f.read()
        json_obj = json.loads(js)

    project_path = json_obj['project_directory']

    sys.path.append(project_path)
    from scripts.data_loader import load_dataset, get_classes, get_data
    from scripts.data_preparation import prepare_dataset, one_hot_encoding, display_unique_labels
    from scripts.data_pipeline_operations import process_data_pipeline, batch_dataset, augment_data, preprocess_data_pipeline, create_ds
    from scripts.model_builder import conv_block, build_decoder, build_encoder,callbacks

except:
    raise Exception('Please configure the path to project directory in the file "config.json". If path is correct, then check if all imports are valid.')
# Out:
# 2026-02-04 18:16:45.602530: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2026-02-04 18:16:45.602548: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2026-02-04 18:16:45.602551: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 12.48 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770225405.602560 2457432 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1770225405.602574 2457432 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Loading dataset from Kaggle
 
PROJ_DIR = project_path
dataset_download_dir = f'{PROJ_DIR}/data'
ROOT_DIR = load_dataset('tawsifurrahman/covid19-radiography-database', dataset_download_dir)
# Out:
# Dataset downloaded successfully at: /Users/uni/project_workspace/pneumonia_detection/data/datasets/tawsifurrahman/covid19-radiography-database/versions/5
# The root directory:  /Users/uni/project_workspace/pneumonia_detection/data/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset

# %%
# Extracting class names from dataset

classes = get_classes(ROOT_DIR)
# Out:
# Retrieveing files from:  /Users/uni/project_workspace/pneumonia_detection/data/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset
# Extracting class names ...
# There are 4 available classes:
#
#  1. COVID
#     |-- images
#     |-- masks
#
#  2. Lung_Opacity
#     |-- images
#     |-- masks
#
#  3. Normal
#     |-- images
#     |-- masks
#
#  4. Viral Pneumonia
#     |-- images
#     |-- masks

# %% [markdown]
# # Exploratory data analysis

# %%
""" 
    This part deals with below aspects of data points - i.e. images:
        1. summarizing data from each class
        2. total number of images in each class
        2. total number of images in each sub-class i.e. X-rays and Masks
"""

count_dict = defaultdict(dict)


for key in classes:
    xray, mask = classes[key]
    count_dict[key]['X-rays'] = len(os.listdir(xray))
    count_dict[key]['Masks'] = len(os.listdir(mask))



count_df = pd.DataFrame(count_dict)
count_df['TOTAL']= count_df.sum(axis=1)
count_df
# Out:
#         COVID  LUNG_OPACITY  NORMAL  VIRAL_PNEUMONIA  TOTAL
# X-rays   3616          6012   10192             1345  21165
# Masks    3616          6012   10192             1345  21165

# %%
# Visualize data count

fig, ax =  plt.subplots(1,2,figsize=(15,5))
sns.barplot(count_df.iloc[:,0:4],ax=ax[0])
plt.pie(count_df.iloc[0,0:4],labels=list(classes.keys()),autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x13acfde20>,
#   <matplotlib.patches.Wedge at 0x13ac6e180>,
#   <matplotlib.patches.Wedge at 0x13acfe150>,
#   <matplotlib.patches.Wedge at 0x13ad330e0>],
#  [Text(0.9453209372067657, 0.5624662884818274, 'COVID'),
#   Text(-0.42334543330748536, 1.0152726944509527, 'LUNG_OPACITY'),
#   Text(-0.3682068593232714, -1.036544118090153, 'NORMAL'),
#   Text(1.0781511930471523, -0.21815133492830643, 'VIRAL_PNEUMONIA')],
#  [Text(0.5156296021127812, 0.3067997937173604, '17%'),
#   Text(-0.23091569089499198, 0.553785106064156, '28%'),
#   Text(-0.20084010508542074, -0.565387700776447, '48%'),
#   Text(0.5880824689348103, -0.11899163723362167, '6%')])

# %%
""" 
    Perform preliminary checks on a small sample of image data, like,
        1. check image dimensionality
        2. verify colour space of the images i.e RGB or single channel images
        3. verify size of the images
"""

samples = get_data(classes,4)       # retrieving 4 samples from each class

# %%
""" 
    Visualizing images with their corresponding masks. Used python image processing library 'Pillow' to extract image specifications like image channels, size, and mode.
"""


from PIL import Image

figure = plt.figure(figsize=(17,15),layout=None)
subfigures = figure.subfigures(1,4)


for i,key in enumerate(samples):
    ax = subfigures[i].subplots(4,2)
    subfigures[i].subplots_adjust(wspace=0.07,hspace=0)
    for row,imgs in enumerate(samples[key]):
        for i in range(len(imgs)):
            x_img = Image.open(imgs[i])
            ax[row,i].imshow(x_img)
            ax[row,i].set_title(f'\nSize:{x_img.size}, \nChannels:{x_img.getbands()}, \nMode:{x_img.mode}',y=-0.4, fontsize=8.5,loc='left')
            ax[row,i].axis('off')
    ax[0,0].annotate(f'{key}:', xy=(0,1.1),xycoords='axes fraction',fontsize=14) 
subfigures[i].suptitle(key,fontsize=20,fontweight='semibold',y=0.90)
    

plt.show()

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ### Data pre-processing will happen as part of data pipeline during model training.
# ### To get an idea of what the pipeline will do during training, the exact same function calls are used in this section - only for demonstration purposes.

# %%
"""
    Defining global variables:
    1. IMAGE_HEIGHT,IMAGE_WIDTH - target image height and width for U-Net model input
    2. IMAGE_CHANNELS - 1 channel i.e. greyscale images for model / memory efficiency, clarity and removing redundant data. 
                        Also in medical diagnostics, value is associated with internsity gradients, edges and textures - rather than from "colour".
    3. RANDOM_STATE -  fixed value to get reproducible results i.e. to reproduce the exact same results across runs, for experimentation purposes.
    4. LEARNING_RATE - a crucial hyperparameter in machine learning / deep learning that that controls the step size for updating model parameters during training 
    5. BATCH_SIZE - number of data samples processed in one go before a model updates its parameters. Tunable parameter for optimal memory utilization.
"""

IMAGE_HEIGHT= 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 1
RANDOM_STATE=42
LEARNING_RATE = 0.0005
BATCH_SIZE=64
CALLBACKS = [],
CLASS_NAMES = list(classes.keys())
N_CLASSES = 4

# %%
""" 
    The pipeline overlays the X-ray images with their corresponding Masks, and sends this single image to U-Net model for learning. 
    This ensures that the model focuses only on the relevant regions in the image, thereby genaralizing faster.
    Here, we visualize the overlaid images using the same sample images as before.

"""

figure = plt.figure(figsize=(10,15),layout=None)
subfigures = figure.subfigures(1,4)

for i,key in enumerate(classes):
    ax = subfigures[i].subplots(4,1)
    subfigures[i].subplots_adjust(wspace=0.07,hspace=0)
    for j,imgs in enumerate(samples[key]):
        x, m = [f for f in imgs]
        x,m,_ = preprocess_data_pipeline([x,m],key)
        ov,label = process_data_pipeline(x,m,key)
        img = ov.numpy()
        ax[j].imshow(img)
        ax[j].set_title(f'\nLabel:{label}, \nSize:{img.shape[0:2]}, \nChannels:{img.shape[-1]}',y=-0.3, fontsize=8.5,loc='left')
        ax[j].axis('off')     
    subfigures[i].suptitle(key,fontsize=14,fontweight='semibold',y=0.90)


plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function preprocess_data_pipeline at 0x1384f14e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function preprocess_data_pipeline at 0x1384f14e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2026-02-04 18:16:46.480741: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# # Preparing Train, Validation and Test Datasets

# %%
""" 
    Segregating the X-rays and Masks in separate lists, while maintaining their corresponding mapping to Labels (also in a separate list)
"""

dict = get_data(classes)
xrays, masks, labels = prepare_dataset(dict)

# %%
# Encoding Labels in binary vectors

ohe_labels = one_hot_encoding(labels)
ohe_labels = np.float16(ohe_labels)

display_unique_labels(ohe_labels,classes)
# Out:
# LABELS:  (21165, 4)
# Vector [0. 0. 0. 1.] corresponds to Class Index: 3 and original label as VIRAL_PNEUMONIA
# Vector [0. 0. 1. 0.] corresponds to Class Index: 2 and original label as NORMAL
# Vector [0. 1. 0. 0.] corresponds to Class Index: 1 and original label as LUNG_OPACITY
# Vector [1. 0. 0. 0.] corresponds to Class Index: 0 and original label as COVID

# %%
# Splitting into Train, Validation and Test sets

from sklearn.model_selection import train_test_split

X_train, X_rem, M_trian, M_rem, y_train,y_rem = train_test_split(xrays,masks,ohe_labels,test_size=0.3,stratify=ohe_labels,random_state=RANDOM_STATE)

X_val, X_test, M_val, M_test, y_val, y_test = train_test_split(X_rem, M_rem, y_rem, test_size=0.5,stratify=y_rem,random_state=RANDOM_STATE )

print(' \nThe number of samples in each split are:')
print('\n - Train dataset size: ',len(X_train))
print('\n - Validation dataset size: ',len(X_val))
print('\n - Test dataset size: ',len(X_test))
# Out:
#
# The number of samples in each split are:
#
#  - Train dataset size:  14815
#
#  - Validation dataset size:  3175
#
#  - Test dataset size:  3175

# %%
# Creating datasets for Training, Validation and Testing

train_ds = create_ds(X_train,M_trian,y_train)
val_ds = create_ds(X_val, M_val, y_val)
test_ds = create_ds(X_test, M_test, y_test)

vec_list = [l for _,l in  train_ds.take(64).as_numpy_iterator()]         # verifying the dataset shuffling 

print('As seen below, after splitting and shuffling the dataset, Train dataset contain samples from all classes:\n')
display_unique_labels(vec_list,classes)
# Out:
# Creating dataset ...
# The tensor specifications for 2 features "X-rays & Masks" and 1 target variable "Labels" are:
#  ((TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None)), TensorSpec(shape=(4,), dtype=tf.float16, name=None))
# (TensorSpec(shape=(128, 128, 1), dtype=tf.float16, name=None),
#  TensorSpec(shape=(4,), dtype=tf.float16, name=None))
#
# The tensor specifications after pre-processing:
#  (TensorSpec(shape=(128, 128, 1), dtype=tf.float16, name=None), TensorSpec(shape=(4,), dtype=tf.float16, name=None))
#
# Creating dataset ...
# The tensor specifications for 2 features "X-rays & Masks" and 1 target variable "Labels" are:
#  ((TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None)), TensorSpec(shape=(4,), dtype=tf.float16, name=None))
# (TensorSpec(shape=(128, 128, 1), dtype=tf.float16, name=None),
#  TensorSpec(shape=(4,), dtype=tf.float16, name=None))
#
# The tensor specifications after pre-processing:
#  (TensorSpec(shape=(128, 128, 1), dtype=tf.float16, name=None), TensorSpec(shape=(4,), dtype=tf.float16, name=None))
#
# Creating dataset ...
# The tensor specifications for 2 features "X-rays & Masks" and 1 target variable "Labels" are:
#  ((TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None)), TensorSpec(shape=(4,), dtype=tf.float16, name=None))
# (TensorSpec(shape=(128, 128, 1), dtype=tf.float16, name=None),
#  TensorSpec(shape=(4,), dtype=tf.float16, name=None))
#
# The tensor specifications after pre-processing:
#  (TensorSpec(shape=(128, 128, 1), dtype=tf.float16, name=None), TensorSpec(shape=(4,), dtype=tf.float16, name=None))
#
# As seen below, after splitting and shuffling the dataset, Train dataset contain samples from all classes:
#
# Vector [0. 0. 0. 1.] corresponds to Class Index: 3 and original label as VIRAL_PNEUMONIA
# Vector [0. 0. 1. 0.] corresponds to Class Index: 2 and original label as NORMAL
# Vector [0. 1. 0. 0.] corresponds to Class Index: 1 and original label as LUNG_OPACITY
# Vector [1. 0. 0. 0.] corresponds to Class Index: 0 and original label as COVID
# 2026-02-04 18:16:46.968850: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Batching only train and validation datasets since its not necessary for test set.

train_ds = batch_dataset(train_ds,BATCH_SIZE,PROJ_DIR)
val_ds = batch_dataset(val_ds,BATCH_SIZE,PROJ_DIR)

# %% [markdown]
# # Build U-NET Model

# %%
l2_regularizer = tf.keras.regularizers.L2(0)

input = tf.keras.layers.Input(shape=(IMAGE_HEIGHT,IMAGE_WIDTH,IMAGE_CHANNELS))

# building encoder
conv1, pool = build_encoder(input,64)
conv2, pool = build_encoder(pool,128)
conv3, pool = build_encoder(pool,256)

# bottleneck layer
base_layer = conv_block(pool,512)

# building decoder
x = build_decoder(base_layer,256,conv3)
x = build_decoder(x,128,conv2)
x = build_decoder(x,64,conv1)


gap = tf.keras.layers.GlobalAveragePooling2D()(x)

output = tf.keras.layers.Dense(512,activation='relu',kernel_regularizer=l2_regularizer)(gap)
output = tf.keras.layers.Dense(4,activation='softmax',kernel_regularizer=l2_regularizer)(output)


model = tf.keras.models.Model(inputs=input,outputs=[output])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        320 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     16,448 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     32,896 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │     65,664 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    131,328 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    262,400 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │    524,800 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │  1,049,088 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ activation_3[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │    524,544 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 32,    │    262,400 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ activation_4[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │    131,200 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 64,    │     65,664 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ activation_5[0][… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │     32,832 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │     16,448 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ activation_6[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     33,280 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4)         │      2,052 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,845,572 (14.67 MB)
#  Trainable params: 3,842,756 (14.66 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %%
import gc
tf.keras.backend.clear_session()
gc.collect()

monitor_metrics = ['accuracy',
                   tf.keras.metrics.AUC(curve='PR',name='auc')
                   ]

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE,clipnorm=1.0),
              loss=tf.keras.losses.CategoricalFocalCrossentropy(),                  # Loss function chosen to handle class imbalance
              metrics=monitor_metrics)

# %%
model.fit(train_ds, epochs=50, callbacks=callbacks('model.keras',CALLBACKS,f'{PROJ_DIR}/models'), validation_data=val_ds)
# Out:
# Epoch 1/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6230 - auc: 0.6796 - loss: 0.1187
# Epoch 1: val_auc improved from None to 0.69106, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 1: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 1: val_loss improved from None to 0.24233, saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
#
# Epoch 1: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 303s 1s/step - accuracy: 0.6903 - auc: 0.7592 - loss: 0.0937 - val_accuracy: 0.6476 - val_auc: 0.6911 - val_loss: 0.2423 - learning_rate: 5.0000e-04
# Epoch 2/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7468 - auc: 0.8260 - loss: 0.0671
# Epoch 2: val_auc improved from 0.69106 to 0.69771, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 2: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 2: val_loss improved from 0.24233 to 0.19941, saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
#
# Epoch 2: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 299s 1s/step - accuracy: 0.7600 - auc: 0.8378 - loss: 0.0640 - val_accuracy: 0.6250 - val_auc: 0.6977 - val_loss: 0.1994 - learning_rate: 5.0000e-04
# Epoch 3/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7789 - auc: 0.8609 - loss: 0.0584
# Epoch 3: val_auc did not improve from 0.69771
#
# Epoch 3: val_loss improved from 0.19941 to 0.15513, saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
#
# Epoch 3: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 299s 1s/step - accuracy: 0.7914 - auc: 0.8718 - loss: 0.0556 - val_accuracy: 0.5845 - val_auc: 0.6472 - val_loss: 0.1551 - learning_rate: 5.0000e-04
# Epoch 4/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8060 - auc: 0.8867 - loss: 0.0516
# Epoch 4: val_auc did not improve from 0.69771
#
# Epoch 4: val_loss did not improve from 0.15513
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 299s 1s/step - accuracy: 0.8100 - auc: 0.8901 - loss: 0.0502 - val_accuracy: 0.3345 - val_auc: 0.3247 - val_loss: 0.4040 - learning_rate: 5.0000e-04
# Epoch 5/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8117 - auc: 0.8964 - loss: 0.0481
# Epoch 5: val_auc did not improve from 0.69771
#
# Epoch 5: val_loss did not improve from 0.15513
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.8202 - auc: 0.9029 - loss: 0.0460 - val_accuracy: 0.5794 - val_auc: 0.5659 - val_loss: 0.1875 - learning_rate: 5.0000e-04
# Epoch 6/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8293 - auc: 0.9074 - loss: 0.0444
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 6: val_auc improved from 0.69771 to 0.73225, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 6: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 6: val_loss did not improve from 0.15513
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - accuracy: 0.8335 - auc: 0.9127 - loss: 0.0424 - val_accuracy: 0.6142 - val_auc: 0.7322 - val_loss: 0.1904 - learning_rate: 5.0000e-04
# Epoch 7/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8516 - auc: 0.9291 - loss: 0.0366
# Epoch 7: val_auc improved from 0.73225 to 0.88805, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 7: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 7: val_loss improved from 0.15513 to 0.05096, saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
#
# Epoch 7: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.8655 - auc: 0.9404 - loss: 0.0327 - val_accuracy: 0.8170 - val_auc: 0.8881 - val_loss: 0.0510 - learning_rate: 1.0000e-04
# Epoch 8/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8736 - auc: 0.9399 - loss: 0.0325
# Epoch 8: val_auc did not improve from 0.88805
#
# Epoch 8: val_loss did not improve from 0.05096
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.8801 - auc: 0.9489 - loss: 0.0293 - val_accuracy: 0.8045 - val_auc: 0.8801 - val_loss: 0.0546 - learning_rate: 1.0000e-04
# Epoch 9/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8819 - auc: 0.9462 - loss: 0.0300
# Epoch 9: val_auc improved from 0.88805 to 0.89252, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 9: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 9: val_loss improved from 0.05096 to 0.05055, saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
#
# Epoch 9: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.8885 - auc: 0.9550 - loss: 0.0269 - val_accuracy: 0.8275 - val_auc: 0.8925 - val_loss: 0.0506 - learning_rate: 1.0000e-04
# Epoch 10/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8850 - auc: 0.9522 - loss: 0.0276
# Epoch 10: val_auc improved from 0.89252 to 0.90090, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 10: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 10: val_loss improved from 0.05055 to 0.04829, saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
#
# Epoch 10: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 303s 1s/step - accuracy: 0.8939 - auc: 0.9606 - loss: 0.0245 - val_accuracy: 0.8351 - val_auc: 0.9009 - val_loss: 0.0483 - learning_rate: 1.0000e-04
# Epoch 11/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8926 - auc: 0.9583 - loss: 0.0250
# Epoch 11: val_auc improved from 0.90090 to 0.90242, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 11: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 11: val_loss did not improve from 0.04829
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.9020 - auc: 0.9661 - loss: 0.0221 - val_accuracy: 0.8371 - val_auc: 0.9024 - val_loss: 0.0494 - learning_rate: 1.0000e-04
# Epoch 12/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9029 - auc: 0.9646 - loss: 0.0223
# Epoch 12: val_auc did not improve from 0.90242
#
# Epoch 12: val_loss did not improve from 0.04829
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.9117 - auc: 0.9716 - loss: 0.0196 - val_accuracy: 0.8272 - val_auc: 0.9018 - val_loss: 0.0501 - learning_rate: 1.0000e-04
# Epoch 13/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9142 - auc: 0.9705 - loss: 0.0196
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
#
# Epoch 13: val_auc did not improve from 0.90242
#
# Epoch 13: val_loss did not improve from 0.04829
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.9217 - auc: 0.9767 - loss: 0.0172 - val_accuracy: 0.8202 - val_auc: 0.8927 - val_loss: 0.0502 - learning_rate: 1.0000e-04
# Epoch 14/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9287 - auc: 0.9773 - loss: 0.0165
# Epoch 14: val_auc improved from 0.90242 to 0.93533, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 14: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 14: val_loss improved from 0.04829 to 0.03855, saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
#
# Epoch 14: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 312s 1s/step - accuracy: 0.9373 - auc: 0.9835 - loss: 0.0139 - val_accuracy: 0.8699 - val_auc: 0.9353 - val_loss: 0.0386 - learning_rate: 2.0000e-05
# Epoch 15/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9376 - auc: 0.9831 - loss: 0.0140
# Epoch 15: val_auc improved from 0.93533 to 0.93908, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 15: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 15: val_loss improved from 0.03855 to 0.03670, saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
#
# Epoch 15: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/loss/model.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.9442 - auc: 0.9865 - loss: 0.0124 - val_accuracy: 0.8763 - val_auc: 0.9391 - val_loss: 0.0367 - learning_rate: 2.0000e-05
# Epoch 16/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9423 - auc: 0.9853 - loss: 0.0129
# Epoch 16: val_auc improved from 0.93908 to 0.93953, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 16: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 16: val_loss did not improve from 0.03670
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.9491 - auc: 0.9881 - loss: 0.0115 - val_accuracy: 0.8785 - val_auc: 0.9395 - val_loss: 0.0367 - learning_rate: 2.0000e-05
# Epoch 17/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9459 - auc: 0.9871 - loss: 0.0120
# Epoch 17: val_auc did not improve from 0.93953
#
# Epoch 17: val_loss did not improve from 0.03670
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.9526 - auc: 0.9895 - loss: 0.0108 - val_accuracy: 0.8763 - val_auc: 0.9394 - val_loss: 0.0370 - learning_rate: 2.0000e-05
# Epoch 18/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9504 - auc: 0.9887 - loss: 0.0112
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.000000262749381e-06.
#
# Epoch 18: val_auc did not improve from 0.93953
#
# Epoch 18: val_loss did not improve from 0.03670
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 320s 1s/step - accuracy: 0.9563 - auc: 0.9908 - loss: 0.0101 - val_accuracy: 0.8750 - val_auc: 0.9394 - val_loss: 0.0374 - learning_rate: 2.0000e-05
# Epoch 19/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9555 - auc: 0.9905 - loss: 0.0102
# Epoch 19: val_auc improved from 0.93953 to 0.94082, saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 19: finished saving model to /Users/uni/project_workspace/pneumonia_detection/models/auc/model.keras
#
# Epoch 19: val_loss did not improve from 0.03670
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.9619 - auc: 0.9926 - loss: 0.0090 - val_accuracy: 0.8763 - val_auc: 0.9408 - val_loss: 0.0384 - learning_rate: 4.0000e-06
# Epoch 20/50
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9572 - auc: 0.9910 - loss: 0.0098
# Epoch 20: val_auc did not improve from 0.94082
#
# Epoch 20: val_loss did not improve from 0.03670
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.9629 - auc: 0.9930 - loss: 0.0087 - val_accuracy: 0.8753 - val_auc: 0.9405 - val_loss: 0.0387 - learning_rate: 4.0000e-06
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %%
def get_train_metrics(model):

    # Function call to get train metrics corresponding to the epoch with lowest 'val_loss'

    best_epoch = np.argmin(model.history.history['val_loss'])
    train_loss = model.history.history['loss'][best_epoch]
    train_accuracy = model.history.history['accuracy'][best_epoch]
    val_loss = model.history.history['val_loss'][best_epoch]
    val_accuracy = model.history.history['val_accuracy'][best_epoch]

    
    print('\n Best epoch: ', best_epoch+1)
    print('\n Train Loss: ', train_loss)
    print('\n Train accuracy: ', train_accuracy)
    print('\n Validation Loss: ', val_loss)
    print('\n Validation accuracy: ', val_accuracy)

    # Plotting graphs
    train_loss_values = model.history.history['val_loss']
    train_accuracy_values = model.history.history['val_accuracy']

    plt.plot(train_accuracy_values, label='train accuracy', linestyle="--")
    plt.plot(train_loss_values, label='train loss', linestyle="--")
    plt.xlabel('epochs')
    plt.grid()
    plt.title(f'Train accuracy and loss')
    plt.legend()

get_train_metrics(model)
# Out:
#  Best epoch:  15
#
#  Train Loss:  0.012396288104355335
#
#  Train accuracy:  0.9441964030265808
#
#  Validation Loss:  0.036702193319797516
#
#  Validation accuracy:  0.8762755393981934
